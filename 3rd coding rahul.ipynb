# %%
import pandas as pd

# %%
pd.read_excel(r"C:\Users\msi 1\OneDrive\Desktop\data1.xlsx")
# Out:
#      name  batch  score
# 0   sweta      6     50
# 1   rahul      8     80
# 2  atharv      7     90

# %%
pd.read_excel(r"C:\Users\msi 1\OneDrive\Desktop\Sales_Report.xlsx")
# Out:
#                            Dee Kay Enterprises Unnamed: 1 Unnamed: 2  \
# 0                         Sales Summary Report        NaN        NaN
# 1                     15/03/2022 to 30/05/2022        NaN        NaN
# 2                                Customer Name      Tax 1      Tax 2
# 3                             24X12LODHISPORTS     -17.13     -17.13
# 4                        ACE SALES CORPORATION    1040.17    1040.17
# ..                                         ...        ...        ...
# 60                                UPHHARCENTER    2784.56    2784.56
# 61                                 VIJAYSPORTS    1360.06    1360.06
# 62  VIJAY STORE FASHION RETAIL PRIVATE LIMITED     519.77     519.77
# 63                      VIKANG THE SPORTS TOWN    3498.95    3498.95
# 64                                       Total  301174.51  301174.51
#
#           Unnamed: 3 Unnamed: 4  Unnamed: 5
# 0                NaN        NaN         NaN
# 1                NaN        NaN         NaN
# ...
